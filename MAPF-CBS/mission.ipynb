# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data/missions.csv", encoding="utf-8-sig") 
df.head()
# Out:
#    order_item_id      type  order_id item_id  requested_quantity  \
# 0           1001      PICK       NaN   KH004                   1
# 1           1002      MOVE    8001.0   NX002                  10
# 2           1003      MOVE    5001.0   KH003                   9
# 3           1004   INBOUND    7001.0   KH004                  23
# 4           1005  OUTBOUND    6001.0   HK003                  19
#
#    processed_quantity  start_location_id  goal_location_id  start_y  start_x  \
# 0                   0                  0               130        2        9
# 1                   0                120               301        1        4
# 2                   0                200               101        9       12
# 3                   0                  0               130        3        5
# 4                   0                400               201        5       13
#
#    goal_y  goal_x rack_id status  priority  assigned_agent
# 0       5       6    G010   WAIT         1               1
# 1       8      14    A012   WAIT         2               4
# 2       1      12    H005   WAIT         2               5
# 3      10       9    G003   WAIT         2               3
# 4       1       3    C002   WAIT         1               4

# %%
n = 960 # 행 개수

# rack_id 리스트 생성 (A001~U012)
rack_letters = [chr(ord('A') + i) for i in range(21)]  # 'A' ~ 'U'
rack_numbers = [f"{j:03d}" for j in range(1, 13)]      # 001 ~ 012
rack_id_list = [f"{row}{col}" for row in rack_letters for col in rack_numbers]

num_agents = 8  # 최대 에이전트 수
assigned_agents = np.tile(np.arange(1, num_agents+1), int(np.ceil(n/num_agents)))[:n]
np.random.shuffle(assigned_agents)  # 랜덤 분배


item_id_prefixes = ['HK', 'KH', 'NX']
item_id_list = [f"{prefix}{str(num).zfill(3)}" for prefix in item_id_prefixes for num in range(1, 6)]

columns = [
    "order_item_id", "type", "order_id", "item_id", "requested_quantity", "processed_quantity",
    "start_location_id", "goal_location_id", "start_y", "start_x", "goal_y", "goal_x",
    "rack_id", "status", "priority", "assigned_agent"
]

df = pd.DataFrame({
    "order_item_id": np.arange(1001, 1001 + n),
    "type": np.random.choice(["INBOUND", "OUTBOUND"], n),
    "order_id": np.random.choice([5001, 6001, 7001, 8001, None], n),
    "item_id": np.random.choice(item_id_list, n),  # 여기서 지정한 리스트에서 랜덤 선택
    "requested_quantity": np.random.randint(1, 25, n),
    "processed_quantity": np.zeros(n, dtype=int),
    "start_location_id": np.random.choice([0, 100, 120, 200, 201, 400, 500], n),
    "goal_location_id": np.random.choice([101, 130, 201, 301, 400, 600], n),
    "start_y": np.random.randint(1, 11, n),
    "start_x": np.random.randint(1, 15, n),
    "goal_y": np.random.randint(1, 11, n),
    "goal_x": np.random.randint(1, 15, n),
    "rack_id": np.random.choice(rack_id_list, n), 
    "status": "WAIT",
    "priority": np.random.choice([1,2,3], n),
    "assigned_agent": assigned_agents 
})

df = df[columns]

df.head(35)
# Out:
#     order_item_id      type order_id item_id  requested_quantity  \
# 0            1001  OUTBOUND     7001   KH001                   1
# 1            1002   INBOUND     7001   NX005                   1
# 2            1003   INBOUND     5001   HK003                  11
# 3            1004   INBOUND     7001   KH005                  23
# 4            1005   INBOUND     7001   KH005                  23
# 5            1006  OUTBOUND     7001   NX005                  15
# 6            1007   INBOUND     7001   NX004                   7
# 7            1008  OUTBOUND     7001   NX001                   3
# 8            1009   INBOUND     5001   HK002                  17
# 9            1010   INBOUND     8001   HK002                  10
# 10           1011  OUTBOUND     7001   NX004                   8
# 11           1012  OUTBOUND     7001   HK001                  14
# 12           1013   INBOUND     6001   HK002                  24
# 13           1014  OUTBOUND     5001   HK004                  11
# 14           1015   INBOUND     6001   NX003                  12
# 15           1016  OUTBOUND     8001   KH002                  20
# 16           1017   INBOUND     6001   HK003                   1
# 17           1018   INBOUND     6001   HK002                  23
# 18           1019  OUTBOUND     8001   HK004                  16
# 19           1020   INBOUND     5001   KH004                  11
# 20           1021  OUTBOUND     None   HK004                  19
# 21           1022  OUTBOUND     5001   NX004                  10
# 22           1023  OUTBOUND     6001   NX003                  20
# 23           1024  OUTBOUND     7001   NX003                  14
# 24           1025  OUTBOUND     7001   NX003                   1
# 25           1026  OUTBOUND     5001   NX004                  17
# 26           1027   INBOUND     6001   HK003                  24
# 27           1028  OUTBOUND     8001   NX001                   2
# 28           1029   INBOUND     None   NX001                  13
# 29           1030   INBOUND     6001   HK002                  13
# 30           1031  OUTBOUND     None   KH005                   6
# 31           1032   INBOUND     6001   KH002                   2
# 32           1033   INBOUND     8001   NX005                   9
# 33           1034  OUTBOUND     None   KH002                  20
# 34           1035   INBOUND     None   KH003                   9
#
#     processed_quantity  start_location_id  goal_location_id  start_y  start_x  \
# 0                    0                500               101        4       13
# 1                    0                120               201        6        9
# 2                    0                201               201        8        7
# 3                    0                  0               101        9        6
# 4                    0                201               201        3        4
# 5                    0                500               400        6        9
# 6                    0                500               101        7        4
# 7                    0                201               201       10       11
# 8                    0                201               130        1       11
# 9                    0                  0               301        8       11
# 10                   0                100               400        7        9
# 11                   0                200               400        8       14
# 12                   0                400               101        2        5
# 13                   0                400               130        8       11
# 14                   0                500               301       10       14
# 15                   0                100               301        5        1
# 16                   0                201               301        8       12
# 17                   0                  0               130        1       14
# 18                   0                120               301        4        1
# 19                   0                100               600        6        2
# 20                   0                200               600        6        2
# 21                   0                  0               101        7        1
# 22                   0                201               201        2       10
# 23                   0                400               600        9       11
# 24                   0                200               301        8       11
# 25                   0                201               600        5        3
# 26                   0                120               301        2       12
# 27                   0                  0               301        9       11
# 28                   0                  0               301        5        4
# 29                   0                500               400        6       12
# 30                   0                200               301       10        8
# 31                   0                201               101        2        5
# 32                   0                100               600        8        1
# 33                   0                100               201        5       12
# 34                   0                200               101        9        6
#
#     goal_y  goal_x rack_id status  priority  assigned_agent
# 0        8       7    J004   WAIT         1               7
# 1        2       8    B002   WAIT         1               3
# 2        6       8    E007   WAIT         3               3
# 3        4      14    U001   WAIT         3               1
# 4        6       8    K002   WAIT         3               8
# 5        1       9    M002   WAIT         3               4
# 6        7       6    F010   WAIT         3               4
# 7        6       2    L004   WAIT         2               8
# 8        2       4    U011   WAIT         1               7
# 9        5       6    K009   WAIT         3               2
# 10       8       3    R008   WAIT         2               3
# 11       8      12    K005   WAIT         2               5
# 12       2       3    G012   WAIT         1               3
# 13       7       7    L011   WAIT         3               1
# 14       1       5    C009   WAIT         2               7
# 15       4       3    P002   WAIT         2               7
# 16       8       1    E012   WAIT         3               1
# 17       1      13    D002   WAIT         3               1
# 18       1       1    J009   WAIT         3               6
# 19       3      10    K004   WAIT         2               4
# 20       8       9    L003   WAIT         1               5
# 21       7       2    F004   WAIT         3               6
# 22      10      14    B003   WAIT         1               5
# 23       8       1    C012   WAIT         2               5
# 24       8       6    K006   WAIT         2               5
# 25       6       5    T010   WAIT         2               3
# 26       9       3    M007   WAIT         3               4
# 27      10       8    C004   WAIT         2               6
# 28       1       4    U002   WAIT         3               5
# 29       8       9    H011   WAIT         1               6
# 30       3      14    D005   WAIT         2               1
# 31       2       4    U004   WAIT         3               4
# 32       7      14    M010   WAIT         3               6
# 33       1       2    O010   WAIT         1               2
# 34       5       4    N004   WAIT         1               3

# %%
df.to_csv("missions2.csv", index=False, encoding="utf-8-sig")
